# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset from CSV file
d=pd.read_csv('/content/student_exam_scores.csv')
d
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
# Select the first 30 rows for analysis
df1=d.head(30)
df1
# Out:
#    student_id  hours_studied  sleep_hours  attendance_percent  \
# 0        S001            8.0          8.8                72.1
# 1        S002            1.3          8.6                60.7
# 2        S003            4.0          8.2                73.7
# 3        S004            3.5          4.8                95.1
# 4        S005            9.1          6.4                89.8
# 5        S006            8.4          5.1                58.5
# 6        S007           10.8          6.0                54.2
# 7        S008            2.0          4.3                75.8
# 8        S009            5.6          5.9                81.6
# 9        S010            1.3          8.9                66.8
# 10       S011            3.4          5.3                90.9
# 11       S012            6.6          7.9                87.6
# 12       S013            1.3          6.3                83.6
# 13       S014            3.2          6.1                61.2
# ...

# %%
# Check the shape of the dataset (rows, columns)
df1.shape
df1.shape
# Out:
# (30, 6)

# %%
#  Check the data types, non-null counts, and memory usage
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          30 non-null     object
#  1   hours_studied       30 non-null     float64
#  2   sleep_hours         30 non-null     float64
#  3   attendance_percent  30 non-null     float64
#  4   previous_scores     30 non-null     int64
#  5   exam_score          30 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
df1.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
df1.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
df1.tail()
# Out:
#    student_id  hours_studied  sleep_hours  attendance_percent  \
# 25       S026            4.7          6.9                62.2
# 26       S027            2.0          6.5                82.8
# 27       S028            2.1          8.3                50.3
# 28       S029           10.3          4.8                87.5
# 29       S030            7.6          8.8                88.5
#
#     previous_scores  exam_score
# 25               63        30.0
# 26               70        29.0
# 27               75        26.5
# 28               73        37.2
# 29               62        36.2

# %%
# Generate summary statistics for numeric columns (mean, min, max)
df1.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count      30.000000    30.000000           30.000000        30.000000
# mean        5.656667     6.826667           72.920000        68.433333
# std         3.318878     1.544051           13.753129        13.574020
# min         1.100000     4.300000           50.300000        41.000000
# 25%         2.825000     5.600000           60.825000        58.250000
# 50%         5.150000     6.750000           73.750000        70.000000
# 75%         8.325000     8.275000           84.500000        80.000000
# max        11.500000     9.000000           95.100000        90.000000
#
#        exam_score
# count   30.000000
# mean    32.706667
# std      6.340833
# min     17.100000
# 25%     29.375000
# 50%     34.400000
# 75%     36.175000
# max     46.000000

# %%
# Check for missing values in the dataset
df1.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
# Check for duplicate rows in the dataset
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count the number of students for each exam score
exam_score=df1.groupby('exam_score')['student_id'].count()
exam_score
# Out:
# exam_score
# 17.1    1
# 18.3    1
# 24.7    1
# 25.0    1
# 26.5    1
# 28.9    1
# 29.0    1
# 29.3    1
# 29.6    1
# 30.0    1
# 30.2    2
# 31.2    1
# 34.0    1
# 34.1    1
# 34.7    1
# 35.1    1
# 35.6    1
# 35.7    1
# 35.8    1
# 35.9    1
# 36.1    1
# 36.2    1
# 36.3    1
# 37.2    1
# 37.9    1
# 39.2    1
# 40.3    1
# 41.1    1
# 46.0    1
# Name: student_id, dtype: int64

# %%
# Plot distribution of exam scores
exam_score=df1.groupby('exam_score')['student_id'].count()
exam_score.plot(kind='bar',color='purple')
plt.title('Distribution of exam_score')
plt.xlabel('student id')
plt.ylabel('exam score')
plt.legend()
plt.show()

# %%
# Plot exam scores of each student
plt.bar(df1["student_id"],df1["exam_score"],color='blue')
plt.xlabel("Student ID")
plt.ylabel("Exam Score")
plt.title("Exam Score of Each Student")
plt.xticks(rotation=90)
plt.show()

# %%
# Get sorted count of each exam score
exam_score_dist=df1["exam_score"].value_counts().sort_index()
exam_score_dist
# Out:
# exam_score
# 17.1    1
# 18.3    1
# 24.7    1
# 25.0    1
# 26.5    1
# 28.9    1
# 29.0    1
# 29.3    1
# 29.6    1
# 30.0    1
# 30.2    2
# 31.2    1
# 34.0    1
# 34.1    1
# 34.7    1
# 35.1    1
# 35.6    1
# 35.7    1
# 35.8    1
# 35.9    1
# 36.1    1
# 36.2    1
# 36.3    1
# 37.2    1
# 37.9    1
# 39.2    1
# 40.3    1
# 41.1    1
# 46.0    1
# Name: count, dtype: int64

# %%
# Plot average exam score vs hours studied
hours_group=df1.groupby("hours_studied")["exam_score"].mean()
hours_group.plot(kind="bar", color="purple")
plt.xlabel("Hours Studied")
plt.ylabel("Average Exam Score")
plt.title("Study Hours vs Exam Score")
plt.show()

# %%
# Plot average exam score vs attendance percentage
attendance_group=df1.groupby("attendance_percent")["exam_score"].mean()
attendance_group.plot(kind="bar", color="purple")
plt.xlabel("Attendance")
plt.ylabel("Average Exam Score")
plt.title("Attendance vs Exam Score")
plt.show()

# %%
# Plot average exam score vs sleep hours
sleep_group=df1.groupby("sleep_hours")["exam_score"].mean()
sleep_group.plot(kind="bar", color="purple")
plt.xlabel("Sleep Hours")
plt.ylabel("Average Exam Score")
plt.title("Sleep Hours vs Exam Score")
plt.show()

# %%
# Plot average exam score vs previous exam scores
prev_group=df1.groupby("previous_scores")["exam_score"].mean()
prev_group.plot(kind="bar",color="purple")
plt.xlabel("Previous Scores")
plt.ylabel("Average Exam Score")
plt.title("Previous Scores vs Exam Score")
plt.show()

# %%
# Drop student_id column and compute correlation between features
df=df1.drop(columns=['student_id'])
correlation=df.corr()
correlation
# Out:
#                     hours_studied  sleep_hours  attendance_percent  \
# hours_studied            1.000000    -0.096328            0.142786
# sleep_hours             -0.096328     1.000000           -0.306799
# attendance_percent       0.142786    -0.306799            1.000000
# previous_scores          0.121445    -0.052725            0.129249
# exam_score               0.780022     0.136918            0.290012
#
#                     previous_scores  exam_score
# hours_studied              0.121445    0.780022
# sleep_hours               -0.052725    0.136918
# attendance_percent         0.129249    0.290012
# previous_scores            1.000000    0.409613
# exam_score                 0.409613    1.000000

# %%
# Plot correlation of each feature with exam score
df2=df1.drop(columns=["student_id"])
df2
correlation=df2.corr()["exam_score"].drop("exam_score")
correlation.plot(kind='bar', color=['purple','black','green','yellow'])
plt.title("Correlation of Features with Exam Score")
plt.xlabel("Features")
plt.ylabel("Correlation Value")
plt.show()
